# %%
# !sudo python3 -m pip install tweepy

# %%
import pandas as pd
import numpy as np
import tweepy

data = np.empty((10, 9))
cols = ['tag', 'id', 'lang', 'created', 'coord_x', 'coord_y', 'user', 'sentiment', 'text']
panda = pd.DataFrame(data, columns=cols, dtype=object)
panda
# Out:
#             tag            id          lang       created       coord_x  \
# 0             0  9.02193e+217  1.61411e+132  1.47907e+248   9.16281e-72
# 1  9.04759e-119  6.19635e+223  9.89804e+164   9.16281e-72   1.09379e-94
# 2   2.95164e-75   3.06371e-57  9.89804e+164   9.16281e-72  1.69812e+137
# 3  2.11827e+257   6.60925e-62   9.16281e-72  6.01124e+175  1.61411e+132
# 4   2.95162e-75  2.13413e+257   6.60925e-62   9.16281e-72   1.42138e-76
# 5   1.42138e-76   2.95164e-75  1.43589e+161  9.89804e+164   9.16281e-72
# 6  9.89804e+164   9.16281e-72   8.30025e-13   9.45956e-76  1.61411e+132
# 7  2.11161e+257  5.77544e+175   1.42138e-76   2.95164e-75   3.06371e-57
# 8   9.16281e-72  3.88591e-109   9.45956e-76  1.61411e+132   2.95164e-75
# 9  6.12574e-154   2.95153e-75  5.96972e+135  9.02193e+217   2.95162e-75
#
#         coord_y          user     sentiment          text
# 0   1.42138e-76  1.11417e+218  1.61411e+132   9.16281e-72
# 1   9.45956e-76  9.89804e+164  3.35456e+251   1.42138e-76
# 2  9.02193e+217   9.45956e-76   9.16281e-72   7.16632e-90
# 3   9.16281e-72   8.30025e-13   9.45956e-76  9.89804e+164
# 4  3.95613e+252  2.13185e+257  1.69725e+137   1.35302e-23
# 5   1.09379e-94   9.45956e-76  9.89804e+164  1.89064e+219
# 6  2.13595e+257  1.69725e+137   1.35302e-23   1.42138e-76
# 7  9.89804e+164   9.16281e-72  3.42134e+180  9.89804e+164
# 8  2.13413e+257  1.69725e+137  1.61411e+132  9.89804e+164
# 9  2.13413e+257   6.60925e-62  9.89804e+164   9.16281e-72

# %%
import pickle
import json
from textblob import TextBlob

consumer_key1        = '2txDFLO3JRcivufznuRJZWZKO'
consumer_secret1     = 'PBHCAuuWafmzz05hyj8zjIEVQUsgzQozWXo6V3AZcwLcr3pArj'
access_token1        = '1000730493434855424-lZU6guxqzbNFJ2LIwjnPCe9Dgny1dz'
access_token_secret1 = 'F6LxC7Bj4tAvcTwhEjzPVJbpQmMxk1QkUCnUQVE64c8s3'

auth = tweepy.OAuthHandler(consumer_key1, consumer_secret1)
auth.set_access_token(access_token1, access_token_secret1)
#api = tweepy.API(auth, parser=JSONParser())
api = tweepy.API(auth)

q           = "merkel -filter:retweets"
geocode     = "47.068611,15.44327,10km"
lang        = 'de'
result_type = 'popular'

tweets = tweepy.Cursor(api.search, q="merkel", lang='de', result_type='popular', tweet_mode='extended').items(10)
#pickle.dump(tweets, open('merkel-de.pkl', 'wb'))

import html
for idx, tweet in enumerate(tweets):    
    panda.loc[idx, 'tag']       = hashtag
    panda.loc[idx, 'id']        = int(tweet.id)
    panda.loc[idx, 'lang']      = tweet.lang
    panda.loc[idx, 'created']   = tweet.created_at
    panda.loc[idx, 'user']      = tweet.user.screen_name    
    panda.loc[idx, 'text']      = html.unescape(tweet.full_text)#.replace("""\n""", "\n")
    panda.loc[idx, 'sentiment'] = TextBlob(panda.loc[idx, 'text']).sentiment.polarity
    
    print(panda.loc[idx, 'text'].translate("en"))
    
    if tweet.place and tweet.place.country:
        print(tweet.place.country)
        
    if tweet.coordinates:
        coordlist = list(tweet.coordinates)
        panda.loc[idx, 'coord_x'] = coordlist[0]
        panda.loc[idx, 'coord_y'] = coordlist[1]
    else:
        panda.loc[idx, 'coord_x'] = int(0)
        panda.loc[idx, 'coord_y'] = int(0)
        
panda[['id']] = panda[['id']].astype(int)
panda.to_pickle('panda-merkel-de.pkl')
pd.set_option('display.max_colwidth', 1000)
panda
# Out:
# #AfD macht Merkel für #Bamf-Skandal verantwortlich. Weidel: „Merkels fataler Plan, ‘aus Illegalität Legalität zu machen’, hat letzten Endes auch die Ordnung der Verfahren im Bamf zusammenbrechen lassen.“ https://t.co/mDT8dAG082
# Unfassbar! "Schutzsuchende" sollen das sein?
# Zeit, die Wahnsinns-Politik von Frau Merkel endlich zu stoppen. Zeit, die Grenzen sofort zu schließen. Zeit für die #AfD.
# ➡️ https://t.co/FGkczvLW4s https://t.co/GbnGwCNHap
# Hierzu braucht es keinen langen Text:
#
# Der #BAMF-Skandal ist ein Merkel-Skandal. »Der Fisch stinkt vom Kopf her!« Ein anständiger Kanzler wäre schon zu Breitscheidplatz zurückgetreten, spätestens aber jetzt. Kurz: #Merkelmussweg!
#
# Alles gesagt – und noch so viele Zeichen übrig … https://t.co/5hAP6ctrwC
# Am Wochenende verkündete die Kanzlerin, in den kommenden 4 Jahren 6 Mrd. € in den Bau von 1,5 Mio. Eigenheimen zu investieren. Die Regierung stelle dieses Geld zu Verfügung, so Merkel. Sieht man sich diese blumigen Versprechungen genauer an, kehrt schnell Ernüchterung ein!
# #AfD https://t.co/3ZGXVWWMBj
# Das Kanzleramt? Es geht noch genauer:
# Die Kanzlerin Angela Merkel trägt die Verantwortung https://t.co/YRzAMqvo9k
# +++ Bamf-Skandal: Verantwortung liegt bei der Führung! +++
# Die falsche Asylpolitik der Bundesregierung zwang das #Bamf, Millionen illegaler Einwanderer durch ein Asylverfahren zu schleusen, das für einen solchen Massenansturm nicht geeignet ist.
# #AfD
#  https://t.co/0ObBObu7SF https://t.co/VS7t8OliU1
# Sie haben sich für Versöhnung und Verständigung ausgesprochen. Auf eine unmenschliche Tat haben Sie mit menschlicher Größe reagiert.Dafür bewundern wir Sie und danken Ihnen – Kanzlerin #Merkel zu Mevlüde Genç,die vor 25Jahren beim Anschlag in #Solingen 5 Familienangehörige verlor https://t.co/YtomoEi8g8
# Im Fall #Skripal verweigert die #Bundesregierung jetzt die Antwort auf unsere Frage, ob sich der #BND #Nowitschok beschafft hat -  aus Gründen des "Staatswohls". Was wollen #Merkel & #Maas verbergen? Wir brauchen eine Entspannungspolitik mit #Russland!
#  https://t.co/sUIPqcTcCL
# Ich werde heute von ungezählten anonymen Merkel-Fans beschimpft, den ganzen Tag schon – als ob es für das, was ich hier »innere Verwahrlosung« nenne, noch nicht genug traurige Beispiele gäbe … 🙄🙄🙄 https://t.co/F8Nguxo3KY
# Soe wie die MSM der Umgang von Merkel und Co. mit Verfassung, Gewaltenteilung und Recht in EU und zuhause nicht kümmert, schauen sie auch nicht auf die Verfassung in Italien.... https://t.co/nyGWfUDY57
#       tag                   id lang              created coord_x coord_y  \
# 0  merkel  1001420356232581120   de  2018-05-29 11:09:53       0       0
# 1  merkel  1001188938852323329   de  2018-05-28 19:50:18       0       0
# 2  merkel  1001128032923475968   de  2018-05-28 15:48:17       0       0
# 3  merkel  1001125402230886400   de  2018-05-28 15:37:50       0       0
# 4  merkel  1001462104598118400   de  2018-05-29 13:55:46       0       0
# 5  merkel  1001502825468264454   de  2018-05-29 16:37:35       0       0
