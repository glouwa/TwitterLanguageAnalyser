# %%
# !sudo python3 -m pip install tweepy

# %%
import pandas as pd
import numpy as np
import tweepy

data = np.empty((10, 9))
cols = ['tag', 'id', 'lang', 'created', 'coord_x', 'coord_y', 'user', 'sentiment', 'text']
panda = pd.DataFrame(data, columns=cols, dtype=object)
panda
# Out:
#             tag            id          lang       created       coord_x  \
# 0  6.91558e-310  6.91558e-310  3.33512e-316  3.33512e-316  6.91551e-310
# 1  6.91551e-310  6.91552e-310  6.91551e-310  5.40324e-317  6.91558e-310
# 2  6.91551e-310  6.91551e-310  5.40305e-317  6.91551e-310  6.91551e-310
# 3  6.91551e-310  6.91551e-310  6.91558e-310  6.91558e-310  6.91558e-310
# 4  5.40296e-317  5.40293e-317  6.91558e-310  6.91551e-310  6.91551e-310
# 5  6.91558e-310  6.91558e-310  6.91558e-310  6.91558e-310  6.91558e-310
# 6  6.91551e-310  6.91557e-310  6.91551e-310  6.91551e-310  6.91558e-310
# 7  6.91551e-310           NaN             0  5.09775e-317  9.88131e-323
# 8             0  3.33516e-316             0             0             0
# 9  4.82378e+228  9.76118e-313  1.31523e+179   4.0616e+228   8.01769e-96
#
#         coord_y          user     sentiment          text
# 0  6.91558e-310  6.91551e-310  6.91551e-310  6.91558e-310
# 1  6.91557e-310  6.91558e-310  6.91551e-310  6.91558e-310
# 2   5.4028e-317  6.91558e-310  6.91558e-310  6.91558e-310
# 3  6.91558e-310  6.91558e-310  6.91552e-310  6.91553e-310
# 4  6.91557e-310  6.91558e-310  6.91551e-310  6.91551e-310
# 5  6.91558e-310  6.91558e-310  6.91558e-310  6.91551e-310
# 6  6.91558e-310  2.45057e-321  2.84582e-321             0
# 7  6.91551e-310  6.91551e-310  6.91558e-310  6.91551e-310
# 8             0             0             0   1.4854e-313
# 9  5.29342e+180  2.04931e+161  8.90429e+247  5.76354e+228

# %%
import pickle
import json
from textblob import TextBlob

consumer_key1        = '2txDFLO3JRcivufznuRJZWZKO'
consumer_secret1     = 'PBHCAuuWafmzz05hyj8zjIEVQUsgzQozWXo6V3AZcwLcr3pArj'
access_token1        = '1000730493434855424-lZU6guxqzbNFJ2LIwjnPCe9Dgny1dz'
access_token_secret1 = 'F6LxC7Bj4tAvcTwhEjzPVJbpQmMxk1QkUCnUQVE64c8s3'

auth = tweepy.OAuthHandler(consumer_key1, consumer_secret1)
auth.set_access_token(access_token1, access_token_secret1)
#api = tweepy.API(auth, parser=JSONParser())
api = tweepy.API(auth)

hashtag     = "türkei"
q           = "{} -filter:retweets".format(hashtag)
geocode     = "47.068611,15.44327,10km"
lang        = 'de'
result_type = 'popular'

tweets = tweepy.Cursor(api.search, q=q, lang='de', result_type='popular', tweet_mode='extended').items(10)
#pickle.dump(tweets, open('merkel-de.pkl', 'wb'))

import html
for idx, tweet in enumerate(tweets):    
    panda.loc[idx, 'tag']       = hashtag
    panda.loc[idx, 'id']        = int(tweet.id)
    panda.loc[idx, 'lang']      = tweet.lang
    panda.loc[idx, 'created']   = tweet.created_at
    panda.loc[idx, 'user']      = tweet.user.screen_name    
    panda.loc[idx, 'text']      = html.unescape(tweet.full_text)
    panda.loc[idx, 'sentiment'] = TextBlob(panda.loc[idx, 'text']).sentiment.polarity
    
    print(panda.loc[idx, 'text'].translate("en"))
    
    if tweet.place and tweet.place.country:
        print(tweet.place.country)
        
    if tweet.coordinates:
        coordlist = list(tweet.coordinates)
        panda.loc[idx, 'coord_x'] = coordlist[0]
        panda.loc[idx, 'coord_y'] = coordlist[1]
    else:
        panda.loc[idx, 'coord_x'] = int(0)
        panda.loc[idx, 'coord_y'] = int(0)
        
panda[['id']] = panda[['id']].astype(int)
panda.to_pickle('panda-merkel-de.pkl')
pd.set_option('display.max_colwidth', 1000)
panda
# Out:
# Polizei löst Protestaktion in #Istanbul von Opfern des Ausnahmezustands gewaltsam auf. Als CHP-Wahlkämpfer, die vor Ort sind, dies lautstark kritisieren, zerstört die Polizei kurzerhand den CHP-Wahlkampfstand.
#
# So viel zu fairen und freien Wahlen in der Türkei. https://t.co/RNRhoeC8wU
# Flüchtlingsboot vor #Antalya gesunken, 9 Geflüchtete ertrunken #Türkei #Refugees https://t.co/ZWvTWZEryR
# Mindestens 44 #Flüchtlinge starben an diesem Wochenende bei Bootsunglücken im #Mittelmeer vor #Tunesien und der #Türkei. Die Inselgruppe #Kerkenna entwickelt sich immer mehr zum Ausgangspunkt für Überfahrten https://t.co/76D2gBauCe
# Bootsunglücke: Migranten vor Türkei und Tunesien ertrunken https://t.co/nDYSwpoV1o #Flüchtlinge #Tunesien
# "Im Vorfeld der Parlaments- und Präsidentschaftswahlen am 24. Juni in der Türkei finden verstärkt Angriffe auf Mitglieder der Demokratischen Partei der Völker (HDP) statt. Zuletzt wurden Vorfälle aus Ankara und Istanbul bekannt" #TürkeiWahl2018  https://t.co/P33Yv04SzD
# Es gibt jetzt schon fertig gestempelte Wahlzettel in der Türkei. Der Diktator will wieder betrügen. Und dann macht er noch mit dem Koran in der Hand Wahlauftritte. Ich glaube Allah hasst Lügner und Betrüger wie ihn. #Diktaturk https://t.co/HVnRZhCaYx
# Türkei 2/2.
# Ba2: Kreditwürdigkeit der Türkei laut @MoodysInvSvc, auf einem Niveau mit Aserbaidschan und Costa Rica.
# Ba3: Kreditwürdigkeit nach der nun angedrohten Herabstufung. Dann wäre die Türkei auf einem Niveau mit Bangladesch und Fidschi.
# @welt https://t.co/OIqQ7XHvow
# Eindrücke aus Rojava: Friedhof und Mahnmal für die Gefallenen in Kobane - Flüchtlinge aus Raqqa - die Türkei hat über viele hundert Kilometer eine Mauer an der Grenze gebaut - bei der YPJ. Freiheit für Afrin!!! https://t.co/h7qciGaGQx
# 5                                                        Es gibt jetzt schon fertig gestempelte Wahlzettel in der Türkei. Der Diktator will wieder betrügen. Und dann macht er noch mit dem Koran in der Hand Wahlauftritte. Ich glaube Allah hasst Lügner und Betrüger wie ihn. #Diktaturk https://t.co/HVnRZhCaYx
# 6                             Türkei 2/2. \nBa2: Kreditwürdigkeit der Türkei laut @MoodysInvSvc, auf einem Niveau mit Aserbaidschan und Costa Rica.\nBa3: Kreditwürdigkeit nach der nun angedrohten Herabstufung. Dann wäre die Türkei auf einem Niveau mit Bangladesch und Fidschi.\n@welt https://t.co/OIqQ7XHvow
# 7                                                                        Eindrücke aus Rojava: Friedhof und Mahnmal für die Gefallenen in Kobane - Flüchtlinge aus Raqqa - die Türkei hat über viele hundert Kilometer eine Mauer an der Grenze gebaut - bei der YPJ. Freiheit für Afrin!!! https://t.co/h7qciGaGQx
# 8                                                                            Der Wahlkampf in der #Türkei wird immer schmutziger: Bei einer Kundgebung beschimpfte Staatschef #Erdogan seinen inhaftierten Herausforderer #Demirtas – und drohte ihm. Die Antwort via Twitter folgt prompt. https://t.co/LGi5Kpj0kv
# 9  Kommunistische Parteien aus vielen Ländern weltweit rufen dazu auf, bei der #TürkeiWahl2018 Kandidaten der Türkischen Kommunistischen Partei zu wählen.\n\nAngesichts der politischen Situation in der Türkei, in der die #HDP jede Stimme gut gebrauchen kann, völlig unverantwortlich. https://t.co/aN1h8bzgsE

# %%
from textblob import TextBlob

print(TextBlob('bad').sentiment)
# Out:
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)

# %%
import polyglot
from polyglot.text import Text

#text = Text("i hate you bastard punk")
text = Text("alles scheiße hier du arschloch Preis")
print(text.language.code)
print(text.entities)
#print(text.polarity)

for w in text.words[:6]:
    print("{:<16}{:>2}".format(w, w.polarity))
# Out:
# de
# []
# alles            0
# scheiße          0
# hier             0
# du               0
# arschloch        0
# Preis            0

# %%
from polyglot.text import Text, Word
word = Word("physik", language="de")
print("Neighbors (Synonms) of {}".format(word)+"\n"+"-"*30)
for w in word.neighbors:
    print("{:<16}".format(w))
print("\n\nThe first 10 dimensions out the {} dimensions\n".format(word.vector.shape[0]))
print(word.vector[:10])
# Out:
# Neighbors (Synonms) of physik
# ------------------------------
# geophysik
# alischen
# Supraleitung
# orient
# alischer
# Quantenoptik
# Nichtlineare
# Gammastrahlen
# Phasenübergänge
# alisch
#
#
# The first 10 dimensions out the 256 dimensions
#
# [ 0.38124222 -0.20368962 -2.0486317   0.767405    1.075586    0.4299595
#  -1.7190336   0.4091796  -0.2284615   0.7349017 ]

# %%
# !polyglot download embeddings2.de
# !polyglot download ner2.de
# !polyglot download sentiment2.de
# !polyglot download sgns2.en
# Out:
#   File "<ipython-input-166-959a854fcaff>", line 1
#     polyglot download embeddings2.de
#                     ^
# SyntaxError: invalid syntax
